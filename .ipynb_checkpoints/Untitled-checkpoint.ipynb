# %%
import requests
import pprint
import json
url = "https://api.exchange.coinbase.com/products"

headers = {"Accept": "application/json"}

response = requests.get(url, headers=headers)

# print(response.text)
product_json = json.loads(response.text)
# pprint.pprint(product_json)

product_list = [x['id'] for x in product_json]
product_list.sort()
pprint.pprint(product_list)
# Out:
# ['1INCH-BTC',
#  '1INCH-EUR',
#  '1INCH-GBP',
#  '1INCH-USD',
#  'AAVE-BTC',
#  'AAVE-EUR',
#  'AAVE-GBP',
#  'AAVE-USD',
#  'ABT-USD',
#  'ACH-USD',
#  'ADA-BTC',
#  'ADA-ETH',
#  'ADA-EUR',
#  'ADA-GBP',
#  'ADA-USD',
#  'ADA-USDC',
#  'ADA-USDT',
#  'AERGO-USD',
#  'AGLD-USD',
#  'AGLD-USDT',
#  'AIOZ-USD',
#  'AIOZ-USDT',
#  'ALCX-EUR',
#  'ALCX-USD',
#  'ALCX-USDT',
#  'ALEPH-USD',
#  'ALGO-BTC',
#  'ALGO-EUR',
#  'ALGO-GBP',
#  'ALGO-USD',
#  'ALICE-USD',
#  'AMP-USD',
#  'ANKR-BTC',
#  'ANKR-EUR',
#  'ANKR-GBP',
#  'ANKR-USD',
#  'APE-EUR',
#  'APE-USD',
#  'APE-USDT',
#  'API3-USD',
#  'API3-USDT',
#  'ARPA-EUR',
#  'ARPA-USD',
#  'ARPA-USDT',
#  'ASM-USD',
#  'ASM-USDT',
#  'AST-USD',
#  'ATA-USD',
#  'ATA-USDT',
#  'ATOM-BTC',
#  'ATOM-EUR',
#  'ATOM-GBP',
#  'ATOM-USD',
#  'ATOM-USDT',
#  'AUCTION-EUR',
#  'AUCTION-USD',
#  'AUCTION-USDT',
#  'AVAX-BTC',
#  'AVAX-EUR',
#  'AVAX-USD',
#  'AVAX-USDT',
#  'AVT-USD',
#  'AXS-BTC',
#  'AXS-EUR',
#  'AXS-USD',
#  'AXS-USDT',
# ...

# %%
# Out:
# [{'auction_mode': False,
#   'base_currency': 'MPL',
#   'base_increment': '0.001',
#   'cancel_only': False,
#   'display_name': 'MPL/USD',
#   'fx_stablecoin': False,
#   'id': 'MPL-USD',
#   'limit_only': False,
#   'margin_enabled': False,
#   'max_slippage_percentage': '0.03000000',
#   'min_market_funds': '1',
#   'post_only': False,
#   'quote_currency': 'USD',
#   'quote_increment': '0.01',
#   'status': 'online',
#   'status_message': '',
#   'trading_disabled': False},
#  {'auction_mode': False,
#   'base_currency': 'NMR',
#   'base_increment': '0.001',
#   'cancel_only': False,
#   'display_name': 'NMR/EUR',
#   'fx_stablecoin': False,
#   'id': 'NMR-EUR',
#   'limit_only': False,
#   'margin_enabled': False,
#   'max_slippage_percentage': '0.03000000',
#   'min_market_funds': '0.84',
#   'post_only': False,
#   'quote_currency': 'EUR',
#   'quote_increment': '0.01',
#   'status': 'online',
#   'status_message': '',
#   'trading_disabled': False},
# ...

# %%
import requests

url = "https://api.exchange.coinbase.com/products/GALA-EUR"

headers = {"Accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"id":"GALA-EUR","base_currency":"GALA","quote_currency":"EUR","quote_increment":"0.0001","base_increment":"1","display_name":"GALA-EUR","min_market_funds":"0.84","margin_enabled":false,"fx_stablecoin":false,"max_slippage_percentage":"0.03000000","post_only":false,"limit_only":false,"cancel_only":false,"trading_disabled":false,"status":"online","status_message":"","auction_mode":false}

# %%
import json
import pprint
import requests
from datetime import datetime, timedelta
delta = timedelta(minutes=300)


end_time = datetime.fromisoformat('2021-11-05T00:00:00')
start_time = datetime.fromisoformat('2021-11-04T23:57:00')

url = f"https://api.exchange.coinbase.com/products/MATIC-USD/candles?granularity=60&start={start_time.isoformat()}&end={end_time.isoformat()}"

headers = {"Accept": "application/json"}

response = requests.get(url, headers=headers)
ret = json.loads(response.text)
pprint.pprint(ret)
# Out:
# [[1636070400, 1.9069, 1.9167, 1.9161, 1.9069, 49062.9],
#  [1636070340, 1.9162, 1.9205, 1.9162, 1.9165, 31728.9],
#  [1636070280, 1.915, 1.9166, 1.9163, 1.9157, 5144],
#  [1636070220, 1.9156, 1.9178, 1.9178, 1.9163, 9327]]

# %%
# 3 TPS
# candle max count 300

# %%
import requests

url = "https://api.exchange.coinbase.com/products/BTC-USD/book?level=2"

headers = {"Accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"bids":[["20519.92","0.045",2],["20519.9","0.00366019",1],["20519.89","0.04",1],["20519.88","0.10780577",1],["20519.87","0.14075",1],["20519.86","0.05",1],["20519.82","0.14075",1],["20519.81","0.14075",1],["20519.39","0.02077657",1],["20519.24","0.02350085",1],["20519.07","0.00187965",1],["20518.79","0.0184275",1],["20518.78","0.02521191",1],["20518.72","0.02275439",1],["20518.71","0.00080169",1],["20518.64","0.07356875",1],["20518.63","0.24364058",1],["20518.59","0.0197153",1],["20518.41","0.01845807",1],["20518.33","0.02128092",1],["20518.29","0.16287287",2],["20518.28","0.14075",1],["20518.21","0.38892859",1],["20518.2","0.12181253",1],["20517.14","0.08294144",1],["20517.13","0.05119063",1],["20517.03","0.12182089",1],["20516.87","0.00215431",1],["20516.69","0.75438167",2],["20516.63","0.34002735",1],["20516.61","0.18352536",3],["20516.6","0.32068533",1],["20515.81","0.68700374",1],["20515.8","0.59170489",1],["20515.79","0.26285757",3],["20515.76","0.785",1],["20515.75","0.1",1],
# ...

# %%
import requests

url = "https://api.exchange.coinbase.com/products/BTC-USD/book?level=1"

headers = {"Accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"bids":[["20521.38","0.07511235",2]],"asks":[["20521.39","0.0500487",3]],"sequence":40490586979,"auction_mode":false,"auction":null}

# %%
import requests

url = "https://api.exchange.coinbase.com/products/BTC-USD/book?level=3"

headers = {"Accept": "application/json"}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
from datetime import date, timedelta
date_base = date.fromisoformat('2021-02-28')
print(date_base)
print(date_base + timedelta(days=2))
# Out:
# 2021-02-28
# 2021-03-02

# %%
import pandas as pd
a = [[1636070400, 1.9069, 1.9167, 1.9161, 1.9069, 49062.9],
 [1636070340, 1.9162, 1.9205, 1.9162, 1.9165, 31728.9],
 [1636070280, 1.915, 1.9166, 1.9163, 1.9157, 5144],
 [1636070220, 1.9156, 1.9178, 1.9178, 1.9163, 9327]]

df = pd.DataFrame(a)
df.columns=["time", "low", "high", "open", "close", "volume"]
print(df)
# Out:
#          time     low    high    open   close   volume
# 0  1636070400  1.9069  1.9167  1.9161  1.9069  49062.9
# 1  1636070340  1.9162  1.9205  1.9162  1.9165  31728.9
# 2  1636070280  1.9150  1.9166  1.9163  1.9157   5144.0
# 3  1636070220  1.9156  1.9178  1.9178  1.9163   9327.0

# %%
import pandas as pd
df = pd.read_parquet('./output/BTC-USD_2022_4.parquet', engine='pyarrow')

# %%
import datetime
datetime.datetime.fromtimestamp(1651345200).isoformat()
# Out:
# '2022-04-30T15:00:00'

# %%
datetime.datetime.fromtimestamp(1651345200).isoformat()
# Out:
# '2022-04-30T15:00:00'

# %%
cur_time = 0
for _, row in df.iterrows():
    if cur_time == 0:
        cur_time = row["time"]
        continue
    now = row["time"]
    if now - cur_time != 60:
        print(f"Problem, now: {now}, cur_time: {cur_time}")
    cur_time = now
# Out:
# Problem, now: 1651345200.0, cur_time: 1651345200.0

# %%
import pandas as pd
df = pd.read_parquet('./procesed/ETH-UDSD/ETH-USD_2022_4.parquet', engine='pyarrow')
print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import pandas as pd
#       2 df = pd.read_parquet('./procesed/ETH-UDSD/ETH-USD_2022_4.parquet', engine='pyarrow')
#       3 print(df)
#
# ModuleNotFoundError: No module named 'pandas'
